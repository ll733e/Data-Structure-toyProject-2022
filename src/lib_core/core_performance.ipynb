# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import os

# %%
dotry = 100
keyword = "지하철"
batchTime = np.zeros(dotry)
for i in range(dotry):
    start = time.time()
    #os.system("./IO")
    os.system("./core \"꽃 속에 잠겨\"");
    batchTime[i] = time.time() - start

plt.title('Team 08 - IO Library Performance test')
plt.xlabel('epcohs')
plt.ylabel('runtime (ms)')
plt.grid()
plt.plot(batchTime)
# Out:
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
# [ 자료구조론 8팀 라이브러리 검색 결과 ]
# "꽃 속에 잠겨"에 대한 검색 결과입니다.
#
# 책 제목		꽃 속에 잠겨
# 책 저자		글 히구치 이치요 | 옮김 강정원
# 발행일자	2020-08-21
# ISBN 정보	978-89-374-2973-6
